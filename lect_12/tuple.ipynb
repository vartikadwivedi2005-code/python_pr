# %% [markdown]
# A tuple is one of Python's four built-in data types used to store collections of data. Think of it as a list that cannot be changed.
#
# 1. Key Characteristics
# -> Ordered: They maintain the order in which elements are defined.
#
# -> Immutable: Once a tuple is created, you cannot add, remove, or change its items.
#
# -> Allow Duplicates: Since items are indexed, you can have multiple identical values.
#
# -> Heterogeneous: You can mix different data types (strings, integers, booleans) in one tuple.

# %%
# Empty tuple
tpl = ()
tpl1 = tuple()
print(tpl,tpl1)
# Out:
# () ()

# %%
# Creating a tuple
fruits = ("apple", "banana", "cherry", "apple")

# Accessing by index
print(fruits[0])  # Output: apple

# Length of a tuple
print(len(fruits)) # Output: 4
# Out:
# apple
# 4

# %%
tpl = 1,
print(type(tpl))
print(tpl)
# Out:
# <class 'tuple'>
# (1,)

# %%
tpl = (2,3,4,5,"hello")
tpl+=(4,6,9)
print(tpl)
# Out:
# (2, 3, 4, 5, 'hello', 4, 6, 9)

# %%
tpl = (2,3,4,5,"hello")
print(id(tpl))
tpl+=(4,6,8)
print(id(tpl))
# Out:
# 2137725466656
# 2137725377824

# %%
tpl = (2,3,4,5,"hello")
tpl=list(tpl)
tpl[3]=90
tpl=tuple(tpl)
print(tpl)
# Out:
# (2, 3, 4, 90, 'hello')

# %%
tpl=(1,2,3,4,5,6,7,8,9)
tpl.count(3)
# Out:
# 1

# %%
tpl=(1,2,3,7,5,54,3,7,53,6,7)
print(sorted(tpl,reverse=True))
# Out:
# [54, 53, 7, 7, 7, 6, 5, 3, 3, 2, 1]

# %%
tpl=(1,2,3,7,5,54,3,7,53,6,7)
tpl[-3::-6]
# Out:
# (53, 3)
