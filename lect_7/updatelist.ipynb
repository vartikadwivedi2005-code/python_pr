# %%
# update the list
list=[3,5,6,8,9]
list.append("hello")
list.append([3,6,7,8])
print(list)
# Out:
# [3, 5, 6, 8, 9, 'hello', [3, 6, 7, 8]]

# %%
# update the list
list=[3,5,6,8,9]
list.append("hello")
list.append([3,6,7,8])
print(list)
print(list[6][-3])
# Out:
# [3, 5, 6, 8, 9, 'hello', [3, 6, 7, 8]]
# 6

# %%
# update the list
list=[3,5,6,8,9]
list.append("hello")
list.append([3,6,7,8])
print(list)

# %%
list = [3,4,6,8,5,4,9,7]
list.insert(-3,8)
print(list)
# Out:
# [3, 4, 6, 8, 5, 8, 4, 9, 7]

# %%
list=[3, 4, 6, 8, 5, 8, 4, 9, 7]
list.extend([7,8,0,9,4,3])
print(list)
# Out:
# [3, 4, 6, 8, 5, 8, 4, 9, 7, 7, 8, 0, 9, 4, 3]

# %%
list=[3, 4, 6, 8, 5, 8, 4, 9, 7]
list+=[1,2,3,5,4]
print(list)
# Out:
# [3, 4, 6, 8, 5, 8, 4, 9, 7, 1, 2, 3, 5, 4]

# %%
# delete element in a list
list=[4,5,6,7,8,9]
del list[3]
print(list)
# Out:
# [4, 5, 6, 8, 9]

# %%
# delete element in a list
list=[4,5,6,7,8,9]
x=list.pop(3)
print(list)
print(x)
# Out:
# [4, 5, 6, 8, 9]
# 7

# %%
# delete element in a list
list=[4,5,6,7,8,9]
list.remove(6)
print(list)
# remove aak hi element ko delete karta hai duplicates ko nahi karta hai.
# Out:
# [4, 5, 7, 8, 9]

# %%
list=[4,5,6,7,9,8,9]
list.count(9)
# Out:
# 2
