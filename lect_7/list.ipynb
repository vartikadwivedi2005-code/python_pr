# %%
x = eval(input("Enter the list:"))
print(type(x))
print(x)
# Out:
# <class 'tuple'>
# (6, 5, 8, 5)

# %%
list =[2,6,4,5,3,7,3,9]
print(list)
for i in range(len(list)):
    if(list[i]%2 == 0):
        list[i]-=5
    else:
        list[i]+=5
print(list)
# Out:
# [2, 6, 4, 5, 3, 7, 3, 9]
# [-3, 1, -1, 10, 8, 12, 8, 14]

# %% [markdown]
# Wap which will take a list from the user and will print the largest element from it.

# %%
# Use a safer name like 'data' instead of 'list'
data = eval(input("Enter a list: "))
print(data)

# Check if the list is not empty
if data:
    largest = max(data)
    print("The largest element is:", largest)
else:
    print("The list is empty.")
# Out:
# The largest element is: 8

# %%
list = eval(input("Enter the list:"))
print(data)
largest = 5
sl = 3 
for i in range(2,len(list)):
    if list[i]>largest:
        sl=largest
        largest = list[i]
    elif list[i]>sl:
        sl=list[i]
print("Largest element is:",largest)
print("Second largest element is:",sl)
# Out:
# (90, 88, 99, 78, 67)
# Largest element is: 99
# Second largest element is: 90
