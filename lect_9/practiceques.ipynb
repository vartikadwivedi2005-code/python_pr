# %% [markdown]
# Write a python program to divide the list into two equal halves and print the sum of each half.

# %%
list = [2,4,6,8,3,5,8,9]
mid = len(list)
first_half = list[:mid]
second_half = list[mid:]
sum_one = sum(first_half)
sum_second = sum(second_half)
print(mid)
print()
# Out:
# 8
# [2, 4, 6, 8, 3, 5, 8, 9]

# %%
list = [2,4,6,8,3,5,8,9]
print(sum(list[:len(list)//2]),sum(list[len(list)//2:]))
print(list)
# Out:
# 20 25
# [2, 4, 6, 8, 3, 5, 8, 9]

# %% [markdown]
# Write a program to insert the product of the first and last elements at the third position in the list.Print the list before and after insertion.
#
# Write a program to print the list of first and last elements of each list of lists.
#
# Write a program to calculate and print the sum of max elements of each list of lists.

# %%
list = [2,4,6,8,3,5,8,9]
product = list[0] * list[7]

print(list)
print(product)
list.insert(3,product)
print(list)
# Out:
# [2, 4, 6, 8, 3, 5, 8, 9]
# 18
# [2, 4, 6, 18, 8, 3, 5, 8, 9]

# %%
list =[[23,45,36],[45,78,67],[68,40,39]]
list1 = []
for i in list:
    list1.append(i[0])
    list1.append(i[-1])
print(list1)
# Out:
# [23, 36, 45, 67, 68, 39]

# %%
list=[[23,45,36],[45,78,67],[68,40,39]]
my_list = []
ans = 0
for i in list:
    ans +=max(i)
print(ans)
# Out:
# 191

# %%
# Write a program to calculate and print the sum of elements in each list of lists and the resultant values .Without using sum() function.

# %%
list=[[23,45,36],[45,78,67],[68,40,39]]
list1=[]
for i in list:
    sum = list[0] + list[1] + list[2]
print(list)
# Out:
# [[23, 45, 36], [45, 78, 67], [68, 40, 39]]

# %% [markdown]
# Write a program which will take a list as input from user and create new list from a given list the new list have all the even numbers from prvious given list.

# %%
x = eval(input("Enter the list:"))
print(x)
# Out:
# (4, 6, 5, 7, 4, 8)

# %%
list = [4, 6, 5, 7, 4, 8]

list1 = []
for i in list:
    if i%2==0:
        list1.append(i)
print(list1)
# Out:
# [4, 6, 4, 8]
