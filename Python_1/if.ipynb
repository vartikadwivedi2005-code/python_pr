# %%
# Conditional Statements in Python - if - if is used to check a condition and execute a block of code if the condition is true.
age = 21
if(age >=18):
    print("Can vote and apply for driving license")

# %%
age = 24
 if(age >=18):  # if condition is true then it will execute the block of code
    print("Can vote")
    print("Can apply for driving license")

# %%
age = 24
  if(True):  # if condition is true then it will execute the block of code
    print("Can vote")
    print("Can apply for driving license")
# agar condition true hai to block of code execute hoga chahe condition me kuch bhi likha ho

# %%
num =5
if(num>2):
    print("Number is greater than 2")
if(num>3):
    print("Number is greater than 3")
