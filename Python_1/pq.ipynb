# %%
# Practice Questions on String Functions in Python
# WAP to input user's first name and print its length.
first_name = input("Enter the first name:")
print("LENGTH OF FIRST NAME",len(first_name))

# %%
# WAP to find the occurance of '$' in the given string.
str = input("Enter the string:")
print("OCCURANCE OF '$'",str.count('$'))

# %%
# wap to input a string and replace all the spaces with '-'.
str = input("Enter the string:")
str = str.replace(" ","-")
print(str)

# %%
# WAP to input user's first name and print the first character of the name.
first_name = input("Enter the first name:")
print("FIRST CHARACTER OF FIRST NAME",first_name[0])
