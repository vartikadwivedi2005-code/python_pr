# %%
# WAP to input user's name, age and height and print them in a sentence.

name = input("Enter your name: ")
age = int(input("Enter your age: "))
height = float(input("Enter your height: "))
print("My name is", name, "and I am", age, "years old. I am", height, "feet tall.")
# Out:
# My name is Vartika and I am 20 years old. I am 5.1 feet tall.

# %%
# WAP to input two numbers and print their sum, difference, product and quotient.
x=5
y=7
z=5
print(id(x),id(y),id(z))  #id - address batata hai
y=9
print(id(x),id(y),id(z))
print(type(x))    #type - varaible ka data type batata hai
# Out:
# 140711960487160 140711960487224 140711960487160
# 140711960487160 140711960487288 140711960487160
# <class 'int'>

# %%
# WAP to input a string and print it in reverse order.
str = input("Enter the string:")
print("REVERSED STRING",str[::-1])
# Out:
# hello world

# %%
# Boolean Data Type in Python
x = True
print(x)
print(type(x))    #type - varaible ka data type batata hai

y = False
print(y)
print(type(y))
# Out:
# True
# <class 'bool'>
# False
# <class 'bool'>

# %%
# Out:
# The area of reactangle is : 15.0

# %%
# Out:
# Circumference of the circle: 37.68
