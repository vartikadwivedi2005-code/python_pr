# %% [markdown]
# <!-- LIST - Python -> Array nahi hoti
# 1) List is Mutable
# 2) Dynamic in nature(size)
# 3) Mixed Datatype values store
# 4) []
# 5) Sequence data structure. -->

# %%
del list  # This removes your 'list' variable so the built-in one works again

list1 = list()
print(list1)
# Out:
# []

# %%
list = [1,2,3,4,5,"hello",[3,4,5],8]
print(list)
# Out:
# [1, 2, 3, 4, 5, 'hello', [3, 4, 5], 8]

# %%
print(list[3])
# Out:
# 4

# %%
print(list[5][-2])
# Out:
# l

# %%
list = [1,2,3,4,5,"hello",[3,4,5],8]
for i in range(len(list)):
    print(list[i])
# Out:
# 1
# 2
# 3
# 4
# 5
# hello
# [3, 4, 5]
# 8
